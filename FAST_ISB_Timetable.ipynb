# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Read Fast Islamabad’s Timetable Using Pandas.

# %%
time_table = pd.read_excel(r"TimeTable_FSC_Fall_2022.xlsx", sheet_name = ['Monday','Tuesday','Wednesday','Thursday','Friday'])                                                  
#time_table

# %%
mon = time_table.get('Monday')          #printing of each day done below
tue = time_table.get('Tuesday')
wed = time_table.get('Wednesday')
thu = time_table.get('Thursday')
fri = time_table.get('Friday')

# %%
#mon = mon.fillna('')    #this removes cells which show 'Nan' and gives a neater look!
mon
# Out:
#              Monday   FSC\nTimeTable for Fall-2022  Unnamed: 2  Unnamed: 3  \
# 0               NaN                            NaN         NaN         NaN
# 1               NaN                            NaN         NaN         NaN
# 2               NaN                            NaN         NaN         NaN
# 3              Room                    08:30-09:50         NaN         NaN
# 4             C-301                      PF (CS-A)         NaN         NaN
# 5             C-302                      AP (CS-B)         NaN         NaN
# 6             C-303         Islamic Studies (CS-C)         NaN         NaN
# 7             C-304                      PF (CS-D)         NaN         NaN
# 8             C-305                Calculus (CS-E)         NaN         NaN
# 9             C-307  Eng Comp (SE-G)   08:30-10:15         NaN         NaN
# 10            C-308  Eng Comp (CS-H)   08:30-10:15         NaN         NaN
# ...

# %%
#tue = tue.fillna('')    #this removes cells which show 'Nan' and gives a neater look!
tue
# Out:
#             Tuesday   FSC\nTimeTable for Fall-2022  Unnamed: 2  Unnamed: 3  \
# 0               NaN                            NaN         NaN         NaN
# 1               NaN                            NaN         NaN         NaN
# 2               NaN                            NaN         NaN         NaN
# 3              Room                    08:30-09:50         NaN         NaN
# 4             C-301                      PF (CS-F)         NaN         NaN
# 5             C-302         Islamic Studies (CS-G)         NaN         NaN
# 6             C-303                Calculus (CS-H)         NaN         NaN
# 7             C-304                      PF (CS-J)         NaN         NaN
# 8             C-305                Calculus (CS-K)         NaN         NaN
# 9             C-307  Eng Comp (CS-A)   08:30-10:15         NaN         NaN
# 10            C-308  Eng Comp (CS-C)   08:30-10:15         NaN         NaN
# ...

# %%
#wed = wed.fillna('')    #this removes cells which show 'Nan' and gives a neater look!
wed
# Out:
#                       FSC\nTimeTable for Fall-2022  Unnamed: 2  Unnamed: 3  \
# 0               NaN                            NaN         NaN         NaN
# 1               NaN                            NaN         NaN         NaN
# 2               NaN                            NaN         NaN         NaN
# 3              Room                    08:30-09:50         NaN         NaN
# 4             C-301                      PF (CS-A)         NaN         NaN
# 5             C-302                      AP (CS-B)         NaN         NaN
# 6             C-303         Islamic Studies (CS-C)         NaN         NaN
# 7             C-304                      PF (CS-D)         NaN         NaN
# 8             C-305                Calculus (CS-E)         NaN         NaN
# 9             C-307                         OS (B)         NaN         NaN
# 10            C-308  Eng Comp (CY-C)   08:30-10:15         NaN         NaN
# ...

# %%
#thu = thu.fillna('')
thu
# Out:
#            Thursday   FSC\nTimeTable for Fall-2022  Unnamed: 2  Unnamed: 3  \
# 0               NaN                            NaN         NaN         NaN
# 1               NaN                            NaN         NaN         NaN
# 2               NaN                            NaN         NaN         NaN
# 3              Room                    08:30-09:50         NaN         NaN
# 4             C-301                      PF (CS-F)         NaN         NaN
# 5             C-302         Islamic Studies (CS-G)         NaN         NaN
# 6             C-303                Calculus (CS-H)         NaN         NaN
# 7             C-304                      PF (CS-J)         NaN         NaN
# 8             C-305                Calculus (CS-K)         NaN         NaN
# 9             C-307                Calculus (AI-A)         NaN         NaN
# 10            C-308                Calculus (AI-B)         NaN         NaN
# ...

# %%
#fri = fri.fillna('')
fri
# Out:
#                         FSC\nTimeTable for Fall-2022  Unnamed: 2  Unnamed: 3  \
# 0               NaN                              NaN         NaN         NaN
# 1               NaN                              NaN         NaN         NaN
# 2               NaN                              NaN         NaN         NaN
# 3              Room                      08:30-09:50         NaN         NaN
# 4             C-301                              NaN         NaN         NaN
# 5             C-302                              NaN         NaN         NaN
# 6             C-303                              NaN         NaN         NaN
# 7             C-304                              PDC         NaN         NaN
# 8             C-305               Comp Vision (AI-J)         NaN         NaN
# 9             C-307                              NaN         NaN         NaN
# 10            C-308      FYP / MS Thesis Evaluations         NaN         NaN
# ...

# %% [markdown]
# # 2. Remove Un necessary Top Rows using pandas.

# %%
mon.drop([0,1,2], axis=0, inplace=True)   #drops the first 3 rows
mon.columns = mon.iloc[0]                 #converting the 1st row into the header
mon = mon[1:]

# %%
mon = mon.dropna(axis=1,how='all')        #dropping all columns in which EVERY value was 'Nan'
mon = mon.set_index('Room')
mon
# Out:
# 3                                  08:30-09:50              10:00-11:20  \
# Room
# C-301                                PF (CS-A)          Calculus (CS-A)
# C-302                                AP (CS-B)                PF (CS-B)
# C-303                   Islamic Studies (CS-C)                AP (CS-C)
# C-304                                PF (CS-D)   Islamic Studies (CS-D)
# C-305                          Calculus (CS-E)                PF (CS-E)
# C-307            Eng Comp (SE-G)   08:30-10:15                      NaN
# C-308            Eng Comp (CS-H)   08:30-10:15                      NaN
# C-309            Eng Comp (CS-K)   08:30-10:15                      NaN
# C-310                                LA (DS-A)                PF (DS-A)
# C-311                              Algo (CY-T)                DB (CY-T)
# C-401                                PF (DS-B)  Pakistan Studies (DS-B)
# C-402                          Calculus (DS-C)                LA (DS-C)
# ...

# %%
tue.drop([0,1,2], axis=0, inplace=True)   #drops the first 3 rows
tue.columns = tue.iloc[0]                 #converting the 1st row into the header
tue = tue[1:]

# %%
tue = tue.dropna(axis=1,how='all')        #dropping all columns in which EVERY value was 'Nan'
tue = tue.set_index('Room')
tue
# Out:
# 3                                  08:30-09:50              10:00-11:20  \
# Room
# C-301                                PF (CS-F)   Islamic Studies (CS-F)
# C-302                   Islamic Studies (CS-G)                PF (CS-G)
# C-303                          Calculus (CS-H)                AP (CS-H)
# C-304                                PF (CS-J)   Islamic Studies (CS-J)
# C-305                          Calculus (CS-K)                PF (CS-K)
# C-307            Eng Comp (CS-A)   08:30-10:15                      NaN
# C-308            Eng Comp (CS-C)   08:30-10:15                      NaN
# C-309            Eng Comp (AI-C)   08:30-10:15                      NaN
# C-310                          Calculus (AI-A)  Pakistan Studies (AI-A)
# C-311                          Discrete (CS-H)              COAL (CS-H)
# C-401                          Calculus (AI-B)                LA (AI-B)
# C-402            Eng Comp (AI-D)   08:30-10:15                      NaN
# ...

# %%
wed.drop([0,1,2], axis=0, inplace=True)   #drops the first 3 rows
wed.columns = wed.iloc[0]                 #converting the 1st row into the header
wed = wed[1:]

# %%
wed = wed.dropna(axis=1,how='all')        #dropping all columns in which EVERY value was 'Nan'
wed = wed.set_index('Room')
wed
# Out:
# 3                                  08:30-09:50              10:00-11:20  \
# Room
# C-301                                PF (CS-A)          Calculus (CS-A)
# C-302                                AP (CS-B)                PF (CS-B)
# C-303                   Islamic Studies (CS-C)                AP (CS-C)
# C-304                                PF (CS-D)   Islamic Studies (CS-D)
# C-305                          Calculus (CS-E)                PF (CS-E)
# C-307                                   OS (B)                PF (CY-B)
# C-308            Eng Comp (CY-C)   08:30-10:15                      NaN
# C-309                                LA (DS-A)                PF (DS-A)
# C-310                                PF (DS-B)  Pakistan Studies (DS-B)
# C-311                              Algo (CY-T)                DB (CY-T)
# C-401                          Calculus (DS-C)                LA (DS-C)
# C-402                                PF (CY-A)          Calculus (CY-A)
# ...

# %%
thu.drop([0,1,2], axis=0, inplace=True)   #drops the first 3 rows
thu.columns = thu.iloc[0]                 #converting the 1st row into the header
thu = thu[1:]

# %%
thu = thu.dropna(axis=1,how='all')        #dropping all columns in which EVERY value was 'Nan'
thu = thu.set_index('Room')
thu
# Out:
# 3                                  08:30-09:50              10:00-11:20  \
# Room
# C-301                                PF (CS-F)   Islamic Studies (CS-F)
# C-302                   Islamic Studies (CS-G)                PF (CS-G)
# C-303                          Calculus (CS-H)                AP (CS-H)
# C-304                                PF (CS-J)   Islamic Studies (CS-J)
# C-305                          Calculus (CS-K)                PF (CS-K)
# C-307                          Calculus (AI-A)  Pakistan Studies (AI-A)
# C-308                          Calculus (AI-B)                LA (AI-B)
# C-309            Eng Comp (DS-A)   08:30-10:15                      NaN
# C-310            Eng Comp (CY-A)   08:30-10:15                      NaN
# C-311                     Data Analysis (DS-N)  Data Warehousing (DS-N)
# C-401                                PF (SE-C)  Pakistan Studies (SE-C)
# C-402                  Pakistan Studies (SE-D)                PF (SE-D)
# ...

# %%
fri.drop([0,1,2], axis=0, inplace=True)   #drops the first 3 rows
fri.columns = fri.iloc[0]                 #converting the 1st row into the header
fri = fri[1:]

# %%
fri = fri.dropna(axis=1,how='all')        #dropping all columns in which EVERY value was 'Nan'
fri = fri.set_index('Room')
fri
# Out:
# 3                                    08:30-09:50  \
# Room
# C-301                                        NaN
# C-302                                        NaN
# C-303                                        NaN
# C-304                                        PDC
# C-305                         Comp Vision (AI-J)
# C-307                                        NaN
# C-308                FYP / MS Thesis Evaluations
# C-309                FYP / MS Thesis Evaluations
# C-310                FYP / MS Thesis Evaluations
# C-311                FYP / MS Thesis Evaluations
# C-401                FYP / MS Thesis Evaluations
# C-402                FYP / MS Thesis Evaluations
# C-403                FYP / MS Thesis Evaluations
# C-404                FYP / MS Thesis Evaluations
# C-405                FYP / MS Thesis Evaluations
# C-406                FYP / MS Thesis Evaluations
# C-407                FYP / MS Thesis Evaluations
# C-408                FYP / MS Thesis Evaluations
# ...

# %% [markdown]
# # 3. Return all the classes of the particular subject (Ask from User) along with Time, Day and Room Number.

# %%
subject = str(input("Enter the subject that you want to see the time table of: "))
# Out:
# Enter the subject that you want to see the time table of: Eng Comp (CS-G)   12:30-02:15

# %%
for i in time_table:
    mm = mon.where(mon==subject).dropna(axis = 0, how = 'all').dropna(axis = 1)
    tt = tue.where(tue==subject).dropna(axis = 0, how = 'all').dropna(axis = 1)
    ww = wed.where(wed==subject).dropna(axis = 0, how = 'all').dropna(axis = 1)
    tH = thu.where(thu==subject).dropna(axis = 0, how = 'all').dropna(axis = 1)
    ff = fri.where(fri==subject).dropna(axis = 0, how = 'all').dropna(axis = 1)

if not mm.empty:
    print("MONDAY \n", mm)
if not tt.empty:
    print("TUESDAY \n", tt)
if not ww.empty:
    print("WEDNESDAY \n", ww)
if not tH.empty:
    print("THURSDAY \n", tH)
if not ff.empty:
    print("FRIDAY \n", ff)
# Out:
# MONDAY
#  3                                NaN
# Room
# C-307  Eng Comp (CS-G)   12:30-02:15

# %% [markdown]
# # 4. Ask the list of Subjects from user and return the classes the of these subjects along with Time, Day and Room Number.

# %%
l_sub = []
no = input("Enter the number of subjects you want to search for: ")
for i in range(0,int(no)):
    s = input("Enter subject name: ")
    l_sub.append(s)

for a in l_sub:
    for b in time_table:
        sM = mon.where(mon==a).dropna(axis = 0, how = 'all').dropna(axis = 1)
        sT = tue.where(tue==a).dropna(axis = 0, how = 'all').dropna(axis = 1)
        sW = wed.where(wed==a).dropna(axis = 0, how = 'all').dropna(axis = 1)
        sTH = thu.where(thu==a).dropna(axis = 0, how = 'all').dropna(axis = 1)
        sF = fri.where(fri==a).dropna(axis = 0, how = 'all').dropna(axis = 1)

    if not sM.empty:
        print("\nMONDAY \n", sM)
    if not sT.empty:
        print("\nTUESDAY \n", sT)
    if not sW.empty:
        print("\nWEDNESDAY \n", sW)
    if not sTH.empty:
        print("\nTHURSDAY \n", sTH)
    if not sF.empty:
        print("\nFRIDAY \n", sF)
# Out:
# Enter the number of subjects you want to search for: 1
# Enter subject name: Eng Comp (CS-G) 12:30-02:15

# %% [markdown]
# # 5. Return the Empty slots of the given Day (Monday, Tuesday, Wednesday, Thursday, Friday).

# %%
emp_mon = mon.isnull()
emp_mon = emp_mon.replace(False, "")
emp_mon = emp_mon.replace(True, "Empty")

emp_mon
# Out:
# 3               08:30-09:50 10:00-11:20 11:30-12:50    NaN 01:00-02:20  \
# Room
# C-301                                                Empty
# C-302                                                Empty
# C-303                                                Empty
# C-304                                                Empty
# C-305                                                Empty
# C-307                             Empty       Empty              Empty
# C-308                             Empty       Empty              Empty
# C-309                             Empty              Empty
# C-310                                                Empty
# C-311                                                Empty
# C-401                                                Empty
# C-402                                                Empty
# C-403                                                Empty
# C-404                                                Empty
# ...

# %%
emp_tue = tue.isnull()
emp_tue = emp_tue.replace(False, "")
emp_tue = emp_tue.replace(True, "Empty")

emp_tue
# Out:
# 3               08:30-09:50 10:00-11:20    NaN 11:30-12:50    NaN    NaN  \
# Room
# C-301                                    Empty              Empty  Empty
# C-302                                    Empty              Empty  Empty
# C-303                                    Empty              Empty  Empty
# C-304                                    Empty              Empty  Empty
# C-305                                    Empty              Empty  Empty
# C-307                             Empty  Empty       Empty         Empty
# C-308                             Empty  Empty       Empty         Empty
# C-309                             Empty              Empty         Empty
# C-310                                    Empty              Empty  Empty
# C-311                                    Empty              Empty  Empty
# C-401                                    Empty              Empty  Empty
# C-402                             Empty  Empty              Empty  Empty
# ...

# %%
emp_wed = wed.isnull()
emp_wed = emp_wed.replace(False, "")
emp_wed = emp_wed.replace(True, "Empty")

emp_wed
# Out:
# 3               08:30-09:50 10:00-11:20 11:30-12:50    NaN 01:00-02:20  \
# Room
# C-301                                                Empty
# C-302                                                Empty
# C-303                                                Empty
# C-304                                                Empty
# C-305                                                Empty
# C-307                                                Empty
# C-308                             Empty       Empty              Empty
# C-309                                                Empty
# C-310                                                Empty
# C-311                                                Empty
# C-401                                                Empty
# C-402                                                Empty
# C-403                                         Empty              Empty
# C-404                                                Empty
# ...

# %%
emp_thu = thu.isnull()
emp_thu = emp_thu.replace(False, "")
emp_thu = emp_thu.replace(True, "Empty")

emp_thu
# Out:
# 3               08:30-09:50 10:00-11:20    NaN 11:30-12:50    NaN    NaN  \
# Room
# C-301                                    Empty              Empty  Empty
# C-302                                    Empty              Empty  Empty
# C-303                                    Empty              Empty  Empty
# C-304                                    Empty              Empty  Empty
# C-305                                    Empty              Empty  Empty
# C-307                                    Empty              Empty  Empty
# C-308                                    Empty              Empty  Empty
# C-309                             Empty              Empty         Empty
# C-310                             Empty  Empty       Empty         Empty
# C-311                                    Empty              Empty  Empty
# C-401                                    Empty              Empty  Empty
# C-402                                    Empty              Empty  Empty
# ...

# %%
emp_fri = fri.isnull()
emp_fri = emp_fri.replace(False, "")
emp_fri = emp_fri.replace(True, "Empty")

emp_fri
# Out:
# 3               08:30-09:50 10:00-11:20 11:30-12:50 02:00-03:20    NaN  \
# Room
# C-301                 Empty                                      Empty
# C-302                 Empty                                      Empty
# C-303                 Empty       Empty                   Empty
# C-304                                         Empty              Empty
# C-305                                         Empty       Empty  Empty
# C-307                 Empty       Empty       Empty       Empty  Empty
# C-308                                                            Empty
# C-309                                                            Empty
# C-310                                                            Empty
# C-311                                                            Empty
# C-401                                                            Empty
# C-402                                                            Empty
# ...

# %% [markdown]
# # 6. Which Classroom is less busy in overall week.

# %%
mon_1 = mon.iloc[:35,:]
#mon_1 = mon.iloc[:38,:]                                                          #if we want to include classes held in rooms without name
sum_mon = mon_1[mon_1.isnull().sum(axis=1) == max(mon_1.isnull().sum(axis=1))]    #return the rows that have the maximum amount of missing values
sum_mon
# Out:
# 3                        08:30-09:50 10:00-11:20 11:30-12:50  \
# Room
# C-308  Eng Comp (CS-H)   08:30-10:15         NaN         NaN
#
# 3                                NaN 01:00-02:20  \
# Room
# C-308  Eng Comp (CS-J)   12:30-02:15         NaN
#
# 3                        02:30-03:50 03:55-05:15 05:20-06:40  06:45-08:05
# Room
# C-308  Eng Comp (CS-F)   02:30-04:15         NaN          NaN         NaN

# %%
tue_1 = tue.iloc[:35,:]
#tue_1 = tue.iloc[:38,:]  if we want to include classes held in rooms without name
sum_tue = tue_1[tue_1.isnull().sum(axis=1) == max(tue_1.isnull().sum(axis=1))]
sum_tue
# Out:
# 3     08:30-09:50 10:00-11:20  NaN         11:30-12:50  NaN  NaN  \
# Room
# A-310         NaN   LA (SE-P)  NaN  Fund of Mgt (SE-P)  NaN  NaN
# A-211         NaN   LA (CS-C)  NaN     Discrete (CS-C)  NaN  NaN
#
# 3           01:00-02:20 02:30-03:50 03:55-05:15 05:20-06:40  06:45-08:05
# Room
# A-310  Mktg Mgt  (SE-Q)         NaN         NaN          NaN         NaN
# A-211   Mktg Mgt (AI-K)         NaN         NaN          NaN         NaN

# %%
wed_1 = wed.iloc[:35,:]
#wed_1 = wed.iloc[:38,:]  if we want to include classes held in rooms without name
sum_wed = wed_1[wed_1.isnull().sum(axis=1) == max(wed_1.isnull().sum(axis=1))]
sum_wed
# Out:
# 3                        08:30-09:50      10:00-11:20          11:30-12:50  \
# Room
# C-409  Eng Comp (SE-D)   08:30-10:15              NaN                  NaN
# B-230                    COAL (CS-A)  Discrete (CS-A)            LA (CS-A)
# A-305                    COAL (CS-C)   Data St (CS-C)          COAL (CS-D)
# A-108                 Data St (SE-P)       HCI (SE-P)  S/w Req Engg (SE-P)
# B-130            S/w Req Engg (SE-Q)   Data St (SE-Q)           HCI (SE-Q)
#
# 3                               NaN       01:00-02:20 02:30-03:50  NaN  \
# Room
# C-409  Eng Comp (SE-C)  12:30-02:15               NaN  PDC (CY-T)  NaN
# B-230                           NaN  Data St (CS-A,Y)         NaN  NaN
# A-305                           NaN    Data St (CS-D)         NaN  NaN
# A-108                           NaN        TBW (CS-D)         NaN  NaN
# B-130                           NaN        SDA (CS-A)         NaN  NaN
#
# 3                03:55-05:15 05:20-06:40  06:45-08:05
# Room
# ...

# %%
thu_1 = thu.iloc[:37,:]
sum_thu = thu_1[thu_1.isnull().sum(axis=1) == max(thu_1.isnull().sum(axis=1))]
sum_thu
# Out:
# 3     08:30-09:50 10:00-11:20  NaN 11:30-12:50  NaN  NaN 01:00-02:20  \
# Room
# B-130         NaN         NaN  NaN         NaN  NaN  NaN      AI (B)
#
# 3     02:30-03:50 03:55-05:15 05:20-06:40  06:45-08:05
# Room
# B-130         NaN         NaN          NaN         NaN

# %%
fri_1 = fri.iloc[:38,:]
sum_fri = fri_1[fri_1.isnull().sum(axis=1) == max(fri_1.isnull().sum(axis=1))]
sum_fri
# Out:
# 3     08:30-09:50 10:00-11:20 11:30-12:50 02:00-03:20  NaN 03:30-04:50  \
# Room
# B-227         NaN         NaN         NaN         NaN  NaN         NaN
# B-229         NaN         NaN         NaN         NaN  NaN         NaN
# B-230         NaN         NaN         NaN         NaN  NaN         NaN
# A-301         NaN         NaN         NaN         NaN  NaN         NaN
# A-302         NaN         NaN         NaN         NaN  NaN         NaN
# A-303         NaN         NaN         NaN         NaN  NaN         NaN
# A-305         NaN         NaN         NaN         NaN  NaN         NaN
# A-310         NaN         NaN         NaN         NaN  NaN         NaN
# A-311         NaN         NaN         NaN         NaN  NaN         NaN
# A-314         NaN         NaN         NaN         NaN  NaN         NaN
# A-315         NaN         NaN         NaN         NaN  NaN         NaN
# A-316         NaN         NaN         NaN         NaN  NaN         NaN
# ...

# %%
m = pd.concat([sum_mon,sum_tue,sum_wed,sum_thu, sum_fri], axis=1, ignore_index=True) 
m = m.dropna(how='all', axis=1)       #dropping columns where all the columns are = Nan
m
# Out:
#                                   0                              3   \
# Room
# C-308  Eng Comp (CS-H)   08:30-10:15  Eng Comp (CS-J)   12:30-02:15
# A-310                            NaN                            NaN
# A-211                            NaN                            NaN
# C-409                            NaN                            NaN
# B-230                            NaN                            NaN
# A-305                            NaN                            NaN
# A-108                            NaN                            NaN
# B-130                            NaN                            NaN
# B-227                            NaN                            NaN
# B-229                            NaN                            NaN
# A-301                            NaN                            NaN
# A-302                            NaN                            NaN
# A-303                            NaN                            NaN
# ...

# %%
sum_total = m[m.isnull().sum(axis=1) == max(m.isnull().sum(axis=1))]
print("Least busy classes are:", sum_total.index.values)
# Out:
# Least busy classes are: ['B-227' 'B-229' 'A-301' 'A-302' 'A-303' 'A-311' 'A-314' 'A-315' 'A-316']

# %% [markdown]
# # 7. Which Lab is the busiest lab in the overall week, return its name.

# %%
mon1 = mon.iloc[37:,:]

s_mon = mon1[mon1.isnull().sum(axis=1) == min(mon1.isnull().sum(axis=1))]     #returns the rows that have the minimum amount of missing values
s_mon
# Out:
# 3                           08:30-09:50 10:00-11:20  \
# Room
# C-Margala 1               PF Lab (CS-G)         NaN
# C-Margala 3    Comp Networks Lab (CS-A)         NaN
# C-Margala 4          Data St Lab (CS-D)         NaN
# C-Rawal 1               IICT Lab (AI-B)         NaN
# C-Rawal 4                    DB Lab (C)         NaN
# A-Karakoram 2           IICT Lab (AI-A)         NaN
# A-Mehran 2         Eng Comp Lab (SE-C1)         NaN
# A-CALL-1           Eng Comp Lab (SE-C2)         NaN
# A-CALL-2           Eng Comp Lab (SE-D1)         NaN
# A-CALL-3           Eng Comp Lab (SE-D2)         NaN
#
# 3                             11:30-12:50  NaN 01:00-02:20  \
# Room
# C-Margala 1                 PF Lab (CS-H)  NaN         NaN
# C-Margala 3    S/w Const & Dev Lab (SE-R)  NaN         NaN
# C-Margala 4                 OS Lab (AI-J)  NaN         NaN
# C-Rawal 1                   PF Lab (CS-F)  NaN         NaN
# C-Rawal 4                 COAL Lab (CS-C)  NaN         NaN
# ...

# %%
tue1 = tue.iloc[37:,:]

s_tue = tue1[tue1.isnull().sum(axis=1) == min(tue1.isnull().sum(axis=1))]
s_tue
# Out:
# 3                       08:30-09:50 10:00-11:20  NaN  \
# Room
# C-Margala 1           PF Lab (CS-B)         NaN  NaN
# C-Margala 3           PF Lab (CS-D)         NaN  NaN
# C-Margala 4           PF Lab (CS-E)         NaN  NaN
# C-Rawal 1           IICT Lab (DS-A)         NaN  NaN
# C-Rawal 4             DB Lab (CS-B)         NaN  NaN
# A-Karakoram 1         PF Lab (DS-B)         NaN  NaN
# A-Karakoram 2         PF Lab (SE-E)         NaN  NaN
# A-Karakoram 3    Data St Lab (SE-Q)         NaN  NaN
# A-Mehran 1            PF Lab (SE-F)         NaN  NaN
# A-Mehran 2          COAL Lab (CS-Z)         NaN  NaN
# A-CALL-1       Eng Comp Lab (DS-C1)         NaN  NaN
# A-CALL-2       Eng Comp Lab (DS-C2)         NaN  NaN
#
# 3                                       11:30-12:50  NaN  \
# Room
# C-Margala 1                           PF Lab (CS-C)  NaN
# C-Margala 3                         COAL Lab (CS-A)  NaN
# C-Margala 4                    Data St Lab (CS-B,Z)  NaN
# ...

# %%
wed1 = wed.iloc[37:,:]

s_wed = wed1[wed1.isnull().sum(axis=1) == min(wed1.isnull().sum(axis=1))]
s_wed
# Out:
# 3                         08:30-09:50 10:00-11:20           11:30-12:50  NaN  \
# Room
# C-Margala 1               IICT (CS-F)         NaN         PF Lab (SE-D)  NaN
# C-Rawal 1               PF Lab (AI-B)         NaN         PF Lab (AI-A)  NaN
# Rawal 3 (B-232)       COAL Lab (CS-D)         NaN    Data St Lab (CS-G)  NaN
# C-Rawal 4        Eng Comp Lab (CY-D1)         NaN         OS Lab (DS-N)  NaN
# A-Karakoram 1              OS Lab (C)         NaN    Data St Lab (CS-C)  NaN
# A-Karakoram 2           PF Lab (SE-C)         NaN         DB Lab (CY-T)  NaN
# A-Karakoram 3    Eng Comp Lab (CY-D2)         NaN       COAL Lab (CS-F)  NaN
# A-Mehran 1              PF Lab (DS-D)         NaN         PF Lab (SE-G)  NaN
# A-Mehran 2       Eng Comp Lab (CS-J1)         NaN  Eng Comp Lab (CY-C1)  NaN
# A-CALL-1         Eng Comp Lab (CS-J2)         NaN  Eng Comp Lab (CY-C2)  NaN
# A-CALL-2         Eng Comp Lab (CS-K1)         NaN  Eng Comp Lab (CS-F1)  NaN
# ...

# %%
thu1 = thu.iloc[37:,:]

s_thu = thu1[thu1.isnull().sum(axis=1) == min(thu1.isnull().sum(axis=1))]
s_thu
# Out:
# 3                       08:30-09:50 10:00-11:20  NaN  \
# Room
# C-Margala 3             IICT (CS-B)         NaN  NaN
# C-Rawal 1           IICT Lab (DS-B)         NaN  NaN
# C-Rawal 4             PF Lab (AI-C)         NaN  NaN
# A-Karakoram 1       IICT Lab (AI-D)         NaN  NaN
# A-Karakoram 2         PF Lab (CY-B)         NaN  NaN
# A-Karakoram 3         OS Lab (CS-A)         NaN  NaN
# A-Mehran 1            PF Lab (DS-C)         NaN  NaN
# A-Mehran 2     Eng Comp Lab (CS-D1)         NaN  NaN
# A-CALL-1       Eng Comp Lab (CS-D2)         NaN  NaN
# A-CALL-2       Eng Comp Lab (CS-E1)         NaN  NaN
# A-CALL-3       Eng Comp Lab (CS-E2)         NaN  NaN
#
# 3                           11:30-12:50  NaN  \
# Room
# C-Margala 3             COAL Lab (CS-B)  NaN
# C-Rawal 1                 PF Lab (DS-A)  NaN
# C-Rawal 4                           NaN  NaN
# A-Karakoram 1  Comp Networks Lab (CS-B)  NaN
# A-Karakoram 2           COAL Lab (DS-U)  NaN
# ...

# %%
fri1 = mon.iloc[37:,:]

s_fri = fri1[fri1.isnull().sum(axis=1) == min(fri1.isnull().sum(axis=1))]
s_fri
# Out:
# 3                           08:30-09:50 10:00-11:20  \
# Room
# C-Margala 1               PF Lab (CS-G)         NaN
# C-Margala 3    Comp Networks Lab (CS-A)         NaN
# C-Margala 4          Data St Lab (CS-D)         NaN
# C-Rawal 1               IICT Lab (AI-B)         NaN
# C-Rawal 4                    DB Lab (C)         NaN
# A-Karakoram 2           IICT Lab (AI-A)         NaN
# A-Mehran 2         Eng Comp Lab (SE-C1)         NaN
# A-CALL-1           Eng Comp Lab (SE-C2)         NaN
# A-CALL-2           Eng Comp Lab (SE-D1)         NaN
# A-CALL-3           Eng Comp Lab (SE-D2)         NaN
#
# 3                             11:30-12:50  NaN 01:00-02:20  \
# Room
# C-Margala 1                 PF Lab (CS-H)  NaN         NaN
# C-Margala 3    S/w Const & Dev Lab (SE-R)  NaN         NaN
# C-Margala 4                 OS Lab (AI-J)  NaN         NaN
# C-Rawal 1                   PF Lab (CS-F)  NaN         NaN
# C-Rawal 4                 COAL Lab (CS-C)  NaN         NaN
# ...

# %%
n = pd.concat([s_mon,s_tue,s_wed,s_thu, s_fri], axis=1, ignore_index=True) 
n = n.dropna(how='all', axis=1)       #dropping columns where all the columns are = Nan
n
# Out:
#                                        0                           2   \
# Room
# C-Margala 1                 PF Lab (CS-G)               PF Lab (CS-H)
# C-Margala 3      Comp Networks Lab (CS-A)  S/w Const & Dev Lab (SE-R)
# C-Margala 4            Data St Lab (CS-D)               OS Lab (AI-J)
# C-Rawal 1                 IICT Lab (AI-B)               PF Lab (CS-F)
# C-Rawal 4                      DB Lab (C)             COAL Lab (CS-C)
# A-Karakoram 2             IICT Lab (AI-A)               PF Lab (CS-K)
# A-Mehran 2           Eng Comp Lab (SE-C1)        Eng Comp Lab (DS-D1)
# A-CALL-1             Eng Comp Lab (SE-C2)        Eng Comp Lab (DS-D2)
# A-CALL-2             Eng Comp Lab (SE-D1)        Eng Comp Lab (SE-G1)
# A-CALL-3             Eng Comp Lab (SE-D2)       Eng Comp Lab (SE-G2)
# A-Karakoram 1                         NaN                         NaN
# A-Karakoram 3                         NaN                         NaN
# ...

# %%
sum_t = n[n.isnull().sum(axis=1) == min(n.isnull().sum(axis=1))]
print("Most busy labs are:", sum_t.index.values)
# Out:
# Most busy labs are: ['C-Rawal 1' 'C-Rawal 4' 'A-Karakoram 2' 'A-Mehran 2' 'A-CALL-1'
#  'A-CALL-2']
